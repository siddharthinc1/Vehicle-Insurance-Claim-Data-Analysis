# %% [markdown]
# # Data collection

# %% [raw]
# Collected data related to Vehicle Insurance claim from kaggle dataset using Python and Pandas. To obtain a comprehensive dataset for analysis.

# %%
import pandas as pd

# %%
df = pd.read_excel("D:\Data Analyst\Projects\Vehicle Insurance Claim Data Analysis\insurance_claims.xlsx")
df
# Out:
#      Age  Policy_number Policy_bind_date Policy_state  Policy_annual_premium  \
# 0     48         521585       2014-10-17           OH                1406.91
# 1     42         342868       2006-06-27           IN                1197.22
# 2     29         687698       2000-09-06           OH                1413.14
# 3     41         227811       1990-05-25           IL                1415.74
# 4     44         367455       2014-06-06           IL                1583.91
# ..   ...            ...              ...          ...                    ...
# 995   38         941851       1991-07-16           OH                1310.80
# 996   41         186934       2014-01-05           IL                1436.79
# 997   34         918516       2003-02-17           OH                1383.49
# 998   62         533940       2011-11-18           IL                1356.92
# 999   60         556080       1996-11-11           OH                 766.19
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [raw]
# Cleaned and Preprocessed the Vehicle Insurance claim data using Pandas and Excel to ensure it's quality, accuracy and reliability for analysis.
# This included examining data types, checking for formatting issues, missing values, duplicates and outliers.

# %%
df.isnull().sum()
# Out:
# Age                            0
# Policy_number                  0
# Policy_bind_date               0
# Policy_state                   0
# Policy_annual_premium          0
# Insured_zip                    0
# Insured_gender                 0
# Insured_occupation             0
# Insured_relationship           0
# Incident_date                  0
# Incident_type                  0
# Collision_type                 0
# Incident_severity              0
# Incident_state                 0
# Incident_city                  0
# Incident_location              0
# Number_of_vehicles_involved    0
# Witnesses                      0
# Total_claim_amount             0
# Injury_claim                   0
# Property_claim                 0
# Vehicle_claim                  0
# Auto_model                     0
# Auto_year                      0
# dtype: int64
